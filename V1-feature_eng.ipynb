# %% [markdown]
# # Working on the class based model that works from MVP5

# %%
import pandas as pd
confs = pd.read_csv('confs.csv')
teams = pd.read_csv('teams.csv')

# %%
confs

# %%
from cfb import cfb
def get_importances(clf):
    import numpy as np
 
    importances = clf.feature_importances_
    #
    # Sort the feature importance in descending order
    #
    sorted_indices = np.argsort(importances)[::-1]

    feat_labels = X.columns

    for f in range(X_train.shape[1]):
        print("%2d) %-*s %f" % (f + 1, 30,
            feat_labels[sorted_indices[f]],
            importances[sorted_indices[f]]))

def show_importances_plot(clf):        
    import matplotlib.pyplot as plt
    import numpy as np
    importances = clf.feature_importances_
    sorted_indices = np.argsort(importances)[::-1]
    plt.title('Feature Importance')
    plt.bar(range(X_train.shape[1]), importances[sorted_indices], align='center')
    plt.xticks(range(X_train.shape[1]), X_train.columns[sorted_indices], rotation=90)
    plt.tight_layout()
    plt.show()
def get_class_metrics():
    preds = df_train_copy[[  'pred']]
    actuals = df_train_copy[[ 'target' ]]
    confusion_matrix(actuals,preds)
    print(classification_report(actuals,preds))

# %%
import pandasql as ps
import pandas as pd
c = cfb.cfb()
df = pd.read_csv('2022_games.csv')
#df = c.get_games_from_cfbd(2022)
#df.to_csv('2022_games.csv')
#df_records = c.get_records(df, c.confs)
# Out:
# /Users/garrettrea/Dropbox/python/cfb/cfb/cfb.py:112: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame([tmp]))
# /Users/garrettrea/Dropbox/python/cfb/cfb/cfb.py:112: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame([tmp]))
# /Users/garrettrea/Dropbox/python/cfb/cfb/cfb.py:112: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame([tmp]))
# /Users/garrettrea/Dropbox/python/cfb/cfb/cfb.py:112: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame([tmp]))
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,LabelBinarizer
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from catboost import CatBoostRegressor

week = 10
df_train = c.get_training_data(week, df_records, confs, teams)
X = df_train.loc[:, ~df_train.columns.isin(c.cols)]
y = df_train.loc[: ,df_train.columns=='target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
clf = RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1)
#clf = XGBClassifier()
#clf.fit(X_train, y_train)
#clf = CatBoostRegressor(iterations=20, learning_rate=1,  depth=2)

clf.fit(X_train, y_train.values.ravel())
df_train['win_prob'] = clf.predict_proba(df_train.loc[:, ~df_train.columns.isin( c.cols)])[:,1]
score = clf.score(X_test, y_test)

# %%
df
# Out:
#     season  week season_type  neutral_site  conference_game  attendance  \
# 0     2022     1     regular         False            False          -1
# 0     2022     1     regular          True             True          -1
# 0     2022     1     regular          True            False          -1
# 0     2022     1     regular          True            False          -1
# 0     2022     1     regular         False            False          -1
# ..     ...   ...         ...           ...              ...         ...
# 0     2022    14     regular         False             True          -1
# 0     2022    14     regular          True             True          -1
# 0     2022    14     regular         False            False          -1
# 0     2022    14     regular          True             True          -1
# 0     2022    14     regular          True             True          -1
#
#                       home_team home_conference home_division home_points  \
# ...

# %%
df_train = c.get_training_data((week+1), df_records, confs, teams)
df_train['win_prob'] = clf.predict_proba(df_train.loc[:, ~df_train.columns.isin( c.cols)])[:,1]
#y_pred = clf.predict(X_test)
#predictions = [round(value) for value in y_pred]
 
# evaluate predictions
#accuracy = accuracy_score(y_test, predictions)
#print("Accuracy: %.2f%%" % (accuracy * 100.0))

# %%
df_train[['team','opp','win_prob']]
# Out:
#                       team                    opp  win_prob
# 0                   Adrian         Olivet College  0.000000
# 1                Air Force             New Mexico  0.000000
# 2                    Akron       Eastern Michigan  0.000000
# 3            Alabama State            Florida A&M  0.000000
# 4                   Albany                  Maine  0.000000
# ..                     ...                    ...       ...
# 298    Wisconsin-La Crosse  Wisconsin-Platteville  0.005263
# 299             Wittenberg        Hilbert College  0.010526
# 300                Wofford                    VMI  0.000000
# 301  Worcester Polytechnic                    MIT  0.000000
# 302                   Yale              Princeton  0.000000
#
# [303 rows x 3 columns]

# %%
res#.loc[(res.team == 'Arkansas') |(res.opp == 'Arkansas')]

# %%
#records_inc#.loc[(records_inc.team == 'Arkansas') |(records_inc.opp == 'Arkansas')]

# %%
df.loc[(df.home_team == 'Arkansas') |(df.away_team == 'Arkansas')][['home_team','away_team','home_points','away_points','week']]
# Out:
#               home_team       away_team  home_points  away_points  week
# 230            Arkansas      Cincinnati         31.0         24.0     1
# 351            Arkansas  South Carolina         44.0         30.0     2
# 911            Arkansas  Missouri State         38.0         27.0     3
# 1219          Texas A&M        Arkansas         23.0         21.0     4
# 1464           Arkansas         Alabama         26.0         49.0     5
# 1594  Mississippi State        Arkansas         40.0         17.0     6
# 2066                BYU        Arkansas         35.0         52.0     7
# 2503             Auburn        Arkansas         27.0         41.0     9
# 3018           Arkansas         Liberty          NaN          NaN    10
# 3156           Arkansas             LSU          NaN          NaN    11
# 3424           Arkansas        Ole Miss          NaN          NaN    12
# 3521           Missouri        Arkansas          NaN          NaN    13

# %%
records.columns
